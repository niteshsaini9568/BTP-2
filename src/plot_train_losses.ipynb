# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_csv = "2022-02-03_22-21-11/train_metrics.csv"

# %%
df_train = pd.read_csv(file_csv)

# %%
df_train.head()
# Out:
#    epoch  loss_gen_gan  loss_gen_l1  loss_dis_real  loss_dis_fake
# 0      1      1.486205     8.819069       0.505067       0.372623
# 1      2      1.386876     8.613539       0.472926       0.503947
# 2      3      0.507886     8.627643       1.131076       0.474387
# 3      4      0.680515     9.210280       0.756877       0.848131
# 4      5      1.155254     8.788004       0.507936       0.719934

# %%
lambda_ = 100

# %%
fig = plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, 1+len(df_train.loss_gen_l1)), df_train.loss_gen_l1 / lambda_, "o-")
plt.grid()
plt.xlabel("epoch")
plt.ylabel("Avg. L1 loss")
plt.title("Generator's avg. L1 loss vs epochs")
fig.show()
# Out:
# /tmp/ipykernel_16113/1193642671.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure(figsize=(12, 9))
plt.plot(np.arange(1, 1+len(df_train.loss_gen_gan)), df_train.loss_gen_gan, "o-", label="Generator's BCE loss to fool Discriminator")
plt.plot(np.arange(1, 1+len(df_train.loss_dis_real)), df_train.loss_dis_real, "o-", label="Discriminator's BCE loss for identifying real")
plt.plot(np.arange(1, 1+len(df_train.loss_dis_fake)), df_train.loss_dis_fake, "o-", label="Discriminator's BCE loss for identifying fake")
plt.grid()
plt.xlabel("epoch")
plt.ylabel("Avg. BCE loss")
plt.legend()
plt.title("Comparison of Generator's and Discriminator's avg. BCE losses vs epochs")
fig.show()
# Out:
# /tmp/ipykernel_16113/2680008184.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
